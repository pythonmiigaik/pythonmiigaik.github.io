# %% [markdown]
# ### Самостоятельная работа

# %% [markdown]
# ### Задача 1

# %% [markdown]
# Пусть задано какое-то предложение. Выведите самое короткое слово в этом предложении.

# %%
#решение

# %% [markdown]
# ### Задача 2

# %% [markdown]
# Пусть задано какое-то предложение. Выведите количество гласных в этом предложении.

# %%
#решение

# %% [markdown]
# ### Задача 3

# %% [markdown]
# Число является палиндром, если он равен числу с цифрами в обратном порядке. Например, 5, 44, 171, 4884 являются палиндромами и 43, 194, 4773 не являются палиндромами. Необходимо найти количество шагов, необходимых для получение палиндрома следующей операцией: число + число в обратном порядке. Например: Пусть число равно 87, тогда 87 + 78 = 165; 165 + 561 = 726; 726 + 627 = 1353; 1353 + 3531 = 4884. Всего 4 шага.

# %%
#решение

# %% [markdown]
# ### Задача 4*

# %% [markdown]
# Ваша задача - отсортировать заданную строку. Каждое слово в строке будет содержать одно число. Это число - это позиция, которую должно иметь слово в результате.
#
# Примечание. Числа могут быть от 1 до 9. Итак, 1 будет первым словом (не 0).
#
# Если входная строка пуста, верните пустую строку. Слова во входной строке будут содержать только допустимые последовательные числа.
#
# Для ввода: «is2 Thi1s T4est 3a» функция должна возвращать «Thi1s is2 3a T4est»

# %%
#решение

# %% [markdown]
# ### Задача 5

# %% [markdown]
# Проверить является ли строка паллиндромом. Например: а роза упала на лапу азора является паллиндромом.

# %%
#решение

# %% [markdown]
# ### Задача 6
# Одними из базовых алгоритмов при изучении языков программирования являются алгоритмы сортировки. Например, есть,так называемая, сортировка пузырьком или сортировка простым обменом. Идея, лежащая в этих последовательных действиях, довольная простая: Начинаем обход списка или массива с первым элемента, затем второй проверяем с первым. Если наша цель состоит в выведении в порядке возрастания, то сравнивая, например второй элемент и первый, и если, второй элемент меньше первого, то меняем их местами. Проводим такие действия с соседними элементами на протяжении всей длины списка - 1. В конце концов, получаем отсортированный список по возрастанию. Ваша цель написать этот алгоритм, элементы в выходном списке должны иметь 2 знака после запятой. *Замечание*: для реализации вам понадобится использовать вложенные циклы, потому что одного прохода по списку или массиву будет недостаточно.
# <br> **Входные данные**: $[1,5,-2]$. **Выходные данные**: $[-2.00,1.00,5.00]$

# %%
#решение
